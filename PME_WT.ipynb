# %%
import warnings
warnings.filterwarnings('ignore')
from LogDensity import LogDensity
from Mixed import Mixed
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %% [markdown]
# # Log density method

# %%
sim = LogDensity(xrange=(-np.pi,np.pi),m=3,nx=800,dt=1e-3,dim=1,plot=0,IC='waitingTime',plotEvery=1)
plt.figure()
plt.plot(sim.pnts_x,sim.getPointsRhoex(),'-k',label = r'$t=0$')
plt.xlabel(r'$x$'); plt.ylabel(r'$\rho$')
sim.simulate(0.125)
plt.plot(sim.pnts_x,sim.rhok.vec,'--r',label = r'$t=0.125$')
sim.simulate(0.25)
plt.plot(sim.pnts_x,sim.rhok.vec,'--b',label = r'$t=0.15$')
plt.legend(frameon=0,loc='upper left',fontsize=10)
plt.show()

# %% [markdown]
# ## Density plots

# %% [markdown]
# m=2

# %%
nxList = [200*2**j for j in range(7)]
dt = 1e-3
m=2
time = [(i+1)*dt for i in range(0,int(.2/dt))]
DEN = []
for nx in nxList:
    b = LogDensity(xrange=(-np.pi,np.pi),m=m,nx=nx,dt=dt,dim=1,plot=0,IC='waitingTime')
    denxR = []
    for t in time:
        b.simulate(t)
        denxR.append(b.rhok.vec[b.initialxRNode])
    DEN.append(denxR)

# %%
fig, ax = plt.subplots()
ax.tick_params(direction="in",which='both',axis='both',
                          bottom=True, top=True, left=True, right=True)
ax.set_ylabel('Density at node $x_R^0$',fontsize=12)
ax.set_xlabel('$t$',fontsize=12)
ax.set_xlim([0, .2]); ax.set_ylim([0, .004])
ax.minorticks_on()
theoreticalWT = 1/2/(m+1)
ax.axvline(x=theoreticalWT,linestyle='-',color='black',label='Theoretical Waiting Time')
for i in range(len(DEN)):
    ax.plot(time,DEN[i],'--',label='N='+str(nxList[i]))
ax.legend(frameon=0,loc='upper left')
plt.show()

# %% [markdown]
# m=3

# %%
nxList = [200*2**j for j in range(7)]
dt = 1e-3
m=3
time = [(i+1)*dt for i in range(0,int(.15/dt))]
DEN = []
for nx in nxList:
    b = LogDensity(xrange=(-np.pi,np.pi),m=m,nx=nx,dt=dt,dim=1,plot=0,IC='waitingTime')
    denxR = []
    for t in time:
        b.simulate(t)
        denxR.append(b.rhok.vec[b.initialxRNode])
    DEN.append(denxR)
# Out:
# Time=0.1500

# %%
fig, ax = plt.subplots()
ax.tick_params(direction="in",which='both',axis='both',
                          bottom=True, top=True, left=True, right=True)
ax.set_ylabel('Density at node $x_R^0$',fontsize=12)
ax.set_xlabel('$t$',fontsize=12)
ax.set_xlim([0, .15]); ax.set_ylim([0, .03])
ax.minorticks_on()
theoreticalWT = 1/2/(m+1)
ax.axvline(x=theoreticalWT,linestyle='-',color='black',label='Theoretical Waiting Time')
for i in range(len(DEN)):
    ax.plot(time,DEN[i],'--',label='N='+str(nxList[i]))
ax.legend(frameon=0,loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9038696253803">

# %% [markdown]
# m=4

# %%
nxList = [200*2**j for j in range(7)]
dt = 1e-3
m =4
time = [(i+1)*dt for i in range(0,int(.15/dt))]
DEN = []
for nx in nxList:
    b = LogDensity(xrange=(-np.pi,np.pi),m=m,nx=nx,dt=dt,dim=1,plot=0,IC='waitingTime')
    denxR = []
    for t in time:
        b.simulate(t)
        denxR.append(b.rhok.vec[b.initialxRNode])
    DEN.append(denxR)

# %%
fig, ax = plt.subplots()
ax.tick_params(direction="in",which='both',axis='both',
                          bottom=True, top=True, left=True, right=True)
ax.set_ylabel('Density at node $x_R^0$',fontsize=12)
ax.set_xlabel('$t$',fontsize=12)
ax.set_xlim([0, .15]); ax.set_ylim([0, .2])
ax.minorticks_on()
theoreticalWT = 1/2/(m+1)
ax.axvline(x=theoreticalWT,linestyle='-',color='black',label='Theoretical Waiting Time')
for i in range(len(DEN)):
    ax.plot(time,DEN[i],'--',label='N='+str(nxList[i]))
ax.legend(frameon=0,loc='upper left')
plt.show()

# %% [markdown]
# # Mixed method

# %%
sim = Mixed(xrange=(-np.pi,np.pi),m=3,nx=800,dt=1e-3,dim=1,plot=0,IC='waitingTime')
plt.figure()
plt.plot(sim.pnts_x,sim.getPointsRhoex(),'-k',label = r'$t=0$')
plt.xlabel(r'$x$'); plt.ylabel(r'$\rho$')
sim.simulate(0.125)
plt.plot(sim.pnts_xC,sim.rhoh.vec,'--r',label = r'$t=0.125$')
sim.simulate(0.25)
plt.plot(sim.pnts_xC,sim.rhoh.vec,'--b',label = r'$t=0.15$')
plt.legend(frameon=0,loc='upper left',fontsize=10)
plt.show()

# %%
nxList = [200*2**j for j in range(7)]
dt = 1e-3
m  = 2
T = .2
time = [(i+1)*dt for i in range(0,int(T/dt))]
DEN = []
for nx in nxList:
    b = Mixed(xrange=(-np.pi,np.pi),m=m,nx=nx,dt=dt,dim=1,plot=0,IC='waitingTime')
    denxR = []
    for t in time:
        b.simulate(t)
        denxR.append(b.rhoh.vec[b.initialxRNode])
    DEN.append(denxR)

# %%
fig, ax = plt.subplots()
ax.tick_params(direction="in",which='both',axis='both',
                          bottom=True, top=True, left=True, right=True)
ax.set_ylabel('Density at node $x_R^0$',fontsize=12)
ax.set_xlabel('$t$',fontsize=12)
ax.set_xlim([0, T]); ax.set_ylim([0, 0.01])
ax.minorticks_on()
theoreticalWT = 1/2/(m+1)
ax.axvline(x=theoreticalWT,linestyle='-',color='black',label='Theoretical Waiting Time')
for i in range(len(DEN)):
    ax.plot(time,DEN[i],'--',label='N='+str(nxList[i]))
ax.legend(frameon=0,loc='upper left')
plt.show()

# %%
nxList = [200*2**j for j in range(7)]
dt = 1e-3
m  = 3
T = .15
time = [(i+1)*dt for i in range(0,int(T/dt))]
DEN = []
for nx in nxList:
    b = Mixed(xrange=(-np.pi,np.pi),m=m,nx=nx,dt=dt,dim=1,plot=0,IC='waitingTime')
    denxR = []
    for t in time:
        b.simulate(t)
        denxR.append(b.rhoh.vec[b.initialxRNode])
    DEN.append(denxR)
# Out:
# ---------------------------------------------------------------------------
# NgException                               Traceback (most recent call last)
# Cell In[6], line 11
#       9 denxR = []
#      10 for t in time:
# ---> 11     b.simulate(t)
#      12     denxR.append(b.rhoh.vec[b.initialxRNode])
#      13 DEN.append(denxR)
#
# File ~\Dropbox\PME\Paper Source Code\Github\OOP\Mixed.py:255, in Mixed.simulate(self, tstop)
#     253 with TaskManager():
#     254     while self.tstart.Get() < tstop-self.dt.Get()/2:
# --> 255         self.takeTimestep()
#     256         self.reDrawPlot()
#     257         if self.printTime:
#
# File ~\Dropbox\PME\Paper Source Code\Github\OOP\Mixed.py:248, in Mixed.takeTimestep(self)
#     246     self.fDG.Assemble()
#     247     self.rhoAvg.vec.data = self.invaDG*self.fDG.vec
# --> 248 it = Newton(self.a, self.gfu, printing=False, maxit=30, maxerr=1e-12)
#     249 self.newtonCount.append(it)
#     250 self.reDrawPlot()
#
# ...

# %%
fig, ax = plt.subplots()
ax.tick_params(direction="in",which='both',axis='both',
                          bottom=True, top=True, left=True, right=True)
ax.set_ylabel('Density at node $x_R^0$',fontsize=12)
ax.set_xlabel('$t$',fontsize=12)
ax.set_xlim([0, T]); ax.set_ylim([0, 0.01])
ax.minorticks_on()
theoreticalWT = 1/2/(m+1)
ax.axvline(x=theoreticalWT,linestyle='-',color='black',label='Theoretical Waiting Time')
for i in range(len(DEN)):
    ax.plot(time,DEN[i],'--',label='N='+str(nxList[i]))
ax.legend(frameon=0,loc='upper left')
plt.show()

# %%
nxList = [200*2**j for j in range(7)]
dt = 1e-3
m  = 4
T = .15
time = [(i+1)*dt for i in range(0,int(T/dt))]
DEN = []
for nx in nxList:
    b = Mixed(xrange=(-np.pi,np.pi),m=m,nx=nx,dt=dt,dim=1,plot=0,IC='waitingTime')
    denxR = []
    for t in time:
        b.simulate(t)
        denxR.append(b.rhoh.vec[b.initialxRNode])
    DEN.append(denxR)
fig, ax = plt.subplots()
ax.tick_params(direction="in",which='both',axis='both',
                          bottom=True, top=True, left=True, right=True)
ax.set_ylabel('Density at node $x_R^0$',fontsize=12)
ax.set_xlabel('$t$',fontsize=12)
ax.set_xlim([0, T]); ax.set_ylim([0, .01])
ax.minorticks_on()
theoreticalWT = 1/2/(m+1)
ax.axvline(x=theoreticalWT,linestyle='-',color='black',label='Theoretical Waiting Time')
for i in range(len(DEN)):
    ax.plot(time,DEN[i],'--',label='N='+str(nxList[i]))
ax.legend(frameon=0,loc='upper left')
plt.show()
