# %%
from LogDensity import LogDensity
from Mixed import Mixed
import numpy as np
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # 1D plots

# %% [markdown]
# Log density

# %%
sim = LogDensity(xrange=(-10,10),s0=3,m=3,nx=200,dt=5e-2,dim=1,plot=1,IC='BB',printTime=True,plotInterface=0)
sim.plot = False
sim.simulate(1)
plt.plot(sim.pnts_x,sim.rhok.vec,'bs',markersize=4,label=r'$\rho(1,x)$')
plt.plot(sim.pnts_x,sim.getPointsRhoex(),'-',color='gray',label=r'$\rho_{exact}(1,x)$')
handles, labels = plt.gca().get_legend_handles_labels()
labels[0],labels[1] = r'$\rho(0,x)$',r'$\rho_{exact}(0,x)$'
labels[1],labels[2] = labels[2],labels[1]
handles[1],handles[2] = handles[2],handles[1]
plt.legend(handles, labels,fontsize=10,frameon=0,loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1169.2308121178999">
# Time=1.0000

# %% [markdown]
# Mixed

# %%
sim = Mixed(xrange=(-10,10),s0=3,m=3,nx=200,dt=5e-2,dim=1,plot=1,IC='BB',printTime=True,plotInterface=0)
sim.plot = False
sim.simulate(1)
plt.plot(sim.pnts_xC,sim.rhoh.vec,'s',color='blue',markersize=4,label=r'$\rho(1,x)$')
plt.plot(sim.pnts_x,sim.getPointsRhoex(),'-',color='gray',label=r'$\rho_{exact}(1,x)$')
handles, labels = plt.gca().get_legend_handles_labels()
labels[0],labels[1] = r'$\rho(0,x)$',r'$\rho_{exact}(0,x)$'
labels[1],labels[2] = labels[2],labels[1]
handles[1],handles[2] = handles[2],handles[1]
plt.legend(handles, labels,fontsize=10,frameon=0,loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1169.2308121178999">
# Time=1.0000

# %% [markdown]
# # 2D Plots

# %%
sim = LogDensity(xrange=(-6,6),s0=1,m=3,nx=32,dt=2.5e-2,dim=2,plot=1,IC='BB',printTime=True,quads=1)
sim.simulate(.2)
sim.generateVTU()
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2105-211-g63bbcb022', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, '…
# Time=0.2000

# %%
sim = Mixed(xrange=(-6,6),s0=1,m=3,nx=32,dt=2.5e-2,dim=2,plot=1,IC='BB',printTime=True,quads=1)
sim.simulate(.2)
sim.generateVTU()
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2105-211-g63bbcb022', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, '…
# Time=0.2000

# %%
sim = LogDensity(xrange=(-6,6),s0=1,m=3,nx=23.4,dt=2.5e-2,dim=2,plot=1,IC='BB',printTime=True,quads=0)
sim.simulate(.2)
sim.generateVTU()
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2105-211-g63bbcb022', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, '…
# Time=0.2000

# %%
sim = Mixed(xrange=(-6,6),s0=1,m=3,nx=32,dt=2.5e-2,dim=2,plot=1,IC='BB',printTime=True,quads=0)
sim.simulate(.2)
sim.generateVTU()
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2105-211-g63bbcb022', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, '…
# Time=0.2000

# %% [markdown]
# # 3D Plots

# %% [markdown]
# ~4100 elements

# %%
sim = LogDensity(xrange=(-6,6),s0=1,m=3,nx=16,dt=2.5e-2,dim=3,plot=0,IC='BB',printTime=True,quads=1)
sim.simulate(.2)
#sim.generateVTU()
print(sim.getL2error(3),sim.getL2error(6))
# Out:
# Time=0.20000.019641428783265743 1.3162167821201067

# %%
sim = LogDensity(xrange=(-6,6),s0=1,m=3,nx=11.73,dt=2.5e-2,dim=3,plot=0,IC='BB',printTime=True,quads=0)
sim.simulate(.2)
#sim.generateVTU()
print(sim.getL2error(3),sim.getL2error(6))
# Out:
# Time=0.20000.0673977313659144 2.2823399965349758
